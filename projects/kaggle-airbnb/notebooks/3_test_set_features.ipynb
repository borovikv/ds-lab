# %% [markdown]
# ## Notebook with feature engineering process

# %% [markdown]
# ### Curated Features list (in addition to columns)
#
# #### 1 Features based on Sessions actions:
# 1. [x] Create features event_i with according to:
#     * event_i means that it's action_info event of order i
#     * take its first order in session, i.e. if events are show_nan_nan, show_view_p3 then values for show_view_p3 is 2
#     * normalize by deviding by total number of events in user's session
# 2. [x] COUNT for each action_type
# 3. [x] MEAN, MAX and other descriptive statistics of secs_elapsed deltas
#
# #### 2 Aggregated on Sessions:
# 1. [x] COUNT DISTINCT of device_type
# 2. [ ] % time spent on each action type
# 3. [ ] count sessions per each device, MODE of Device type
# 4. [ ] given that timestamp_first_active is the start of the session, analyze hour (0-23) of activity
#
# #### 3 Transformed from users:
# 1. [x] Hour of first activity - users['hour_factive'] = users.timestamp_first_active.dt.hour
# 2. [x] date of week of account_created
#
# **TODO**: use age_gender_bktd and countries data for features generation

# %%
import pandas as pd
from datetime import datetime
from tqdm.notebook import tqdm
import numpy as np
from scipy import stats
from collections import Counter

pd.options.display.float_format = "{:.2f}".format
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
tqdm.pandas()
# %load_ext autotime
# Out:
# time: 410 µs (started: 2021-08-16 10:05:02 +00:00)

# %% [markdown]
# ### 0. Loading Data

# %%
users = pd.read_parquet('../data/processed/test_users.parquet')
users.shape
# Out:
# (62096, 14)
# time: 135 ms (started: 2021-08-16 10:05:02 +00:00)

# %%
sessions = pd.read_parquet('../data/processed/sessions_test.parquet')
sessions.shape
# Out:
# (4934245, 7)
# time: 1.8 s (started: 2021-08-16 10:05:02 +00:00)

# %%
users.date_account_created = users.date_account_created.apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
users.timestamp_first_active = users.timestamp_first_active.apply(lambda x: datetime.strptime(str(x), '%Y%m%d%H%M%S'))
# Out:
# time: 3.09 s (started: 2021-08-16 10:05:04 +00:00)

# %%
users.head()
# Out:
#            id date_account_created timestamp_first_active     gender   age  \
# 0  5uwns89zht           2014-07-01    2014-07-01 00:00:06     FEMALE 35.00
# 1  jtl0dijy2j           2014-07-01    2014-07-01 00:00:51  -unknown-   NaN
# 2  xx0ulgorjt           2014-07-01    2014-07-01 00:01:48  -unknown-   NaN
# 3  6c6puo6ix0           2014-07-01    2014-07-01 00:02:15  -unknown-   NaN
# 4  czqhjk3yfe           2014-07-01    2014-07-01 00:03:05  -unknown-   NaN
#
#   signup_method  signup_flow language affiliate_channel affiliate_provider  \
# 0      facebook            0       en            direct             direct
# 1         basic            0       en            direct             direct
# 2         basic            0       en            direct             direct
# 3         basic            0       en            direct             direct
# 4         basic            0       en            direct             direct
#
#   first_affiliate_tracked signup_app first_device_type  first_browser
# 0               untracked      Moweb            iPhone  Mobile Safari
# 1               untracked      Moweb            iPhone  Mobile Safari
# 2                  linked        Web   Windows Desktop         Chrome
# 3                  linked        Web   Windows Desktop             IE
# 4               untracked        Web       Mac Desktop         Safari
# time: 37.3 ms (started: 2021-08-16 10:05:07 +00:00)

# %%
sessions.head()
# Out:
#       user_id        action action_type        action_detail device_type  \
# 0  5uwns89zht          show        view         user_profile   -unknown-
# 1  5uwns89zht        search       click  view_search_results   -unknown-
# 2  5uwns89zht        search       click  view_search_results   -unknown-
# 3  5uwns89zht          show        view                   p3   -unknown-
# 4  5uwns89zht  authenticate      submit                login      iPhone
#
#    secs_elapsed                       action_info
# 0         79.00            show_view_user_profile
# 1      17962.00  search_click_view_search_results
# 2      64883.00  search_click_view_search_results
# 3      31180.00                      show_view_p3
# 4           NaN         authenticate_submit_login
# time: 33.3 ms (started: 2021-08-16 10:05:07 +00:00)

# %% [markdown]
# ### 2. Getting features based on Sessions

# %%
sessions.secs_elapsed.fillna(-1, inplace=True)
sessions.sort_values(['user_id', 'secs_elapsed'], inplace=True)
sessions.reset_index(drop=True, inplace=True)
sessions.shape
# Out:
# (4934245, 7)
# time: 4.84 s (started: 2021-08-16 10:05:07 +00:00)

# %%
sessions.head(10)
# Out:
#       user_id               action       action_type        action_detail  \
# 0  0010k6l0om             callback  partner_callback       oauth_response
# 1  0010k6l0om       search_results             click  view_search_results
# 2  0010k6l0om  similar_listings_v2              None                 None
# 3  0010k6l0om                 show              view                   p3
# 4  0010k6l0om                 show              None                 None
# 5  0010k6l0om                 show              None                 None
# 6  0010k6l0om  similar_listings_v2              None                 None
# 7  0010k6l0om                 show              None                 None
# 8  0010k6l0om                 show              None                 None
# 9  0010k6l0om                 show              None                 None
#
#    device_type  secs_elapsed                               action_info
# 0  Mac Desktop         -1.00  callback_partner_callback_oauth_response
# 1  Mac Desktop          3.00  search_results_click_view_search_results
# 2  Mac Desktop          9.00               similar_listings_v2_nan_nan
# 3  Mac Desktop         22.00                              show_view_p3
# 4  Mac Desktop         26.00                              show_nan_nan
# 5  Mac Desktop         30.00                              show_nan_nan
# 6  Mac Desktop         34.00               similar_listings_v2_nan_nan
# 7  Mac Desktop         36.00                              show_nan_nan
# 8  Mac Desktop         39.00                              show_nan_nan
# 9  Mac Desktop         45.00                              show_nan_nan
# time: 21.1 ms (started: 2021-08-16 10:05:12 +00:00)

# %% [markdown]
# ### 2.1 Generating features based on action_info Events vs its Order in the session stream with Normalization
#
# Sessions actions:
# Create features event_i with according to:
#     * event_i means that it's action_info event of order i
#     * take its first order in session, i.e. if events are show_nan_nan, show_view_p3 then values for show_view_p3 is 2
#     * normalize by deviding by total number of events in user's session

# %%
actions_info = list(sessions.action_info.unique())
len(actions_info)
# Out:
# 336
# time: 634 ms (started: 2021-08-16 10:05:12 +00:00)

# %%
tmp = sessions[['user_id', 'action_info']].groupby('user_id', as_index=False).agg(list)
tmp.shape
# Out:
# (61664, 2)
# time: 2.43 s (started: 2021-08-16 10:05:13 +00:00)

# %%
tmp['size'] = tmp.action_info.apply(lambda x: len(x))
# Out:
# time: 55.4 ms (started: 2021-08-16 10:05:15 +00:00)

# %%
tmp.head()
# Out:
#       user_id                                        action_info  size
# 0  0010k6l0om  [callback_partner_callback_oauth_response, sea...    62
# 1  0031awlkjq  [authenticate_view_login_page, dashboard_view_...     8
# 2  00378ocvlh  [create_submit_create_user, similar_listings_v...    73
# 3  0048rkdgb1  [create_submit_signup, show_view_user_profile,...    46
# 4  0057snrdpu  [authenticate_view_login_page, show_view_p3, s...    28
# time: 23.8 ms (started: 2021-08-16 10:05:15 +00:00)

# %%
tmp.columns = ['user_id', 'action_info', 'seassion_length']
# Out:
# time: 1.31 ms (started: 2021-08-16 10:05:15 +00:00)

# %%
def find_action_info_pos(ai, ais):
    try:
        return ais.index(ai) + 1
    except ValueError:
        return None
# Out:
# time: 6.37 ms (started: 2021-08-16 10:05:15 +00:00)

# %%
for ai in tqdm(actions_info):
    tmp[f'ai_{ai}'] = tmp.action_info.apply(lambda x: find_action_info_pos(ai, x)) / tmp.size
# Out:
#   0%|          | 0/336 [00:00<?, ?it/s]
# /tmp/ipykernel_1336/1298815738.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider using pd.concat instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   tmp[f'ai_{ai}'] = tmp.action_info.apply(lambda x: find_action_info_pos(ai, x)) / tmp.size
# time: 1min (started: 2021-08-16 10:05:15 +00:00)

# %%
tmp.head()
# Out:
#       user_id                                        action_info  \
# 0  0010k6l0om  [callback_partner_callback_oauth_response, sea...
# 1  0031awlkjq  [authenticate_view_login_page, dashboard_view_...
# 2  00378ocvlh  [create_submit_create_user, similar_listings_v...
# 3  0048rkdgb1  [create_submit_signup, show_view_user_profile,...
# 4  0057snrdpu  [authenticate_view_login_page, show_view_p3, s...
#
#    seassion_length  ai_callback_partner_callback_oauth_response  \
# 0               62                                         0.00
# 1                8                                          NaN
# 2               73                                          NaN
# 3               46                                          NaN
# 4               28                                          NaN
#
#    ai_search_results_click_view_search_results  \
# 0                                         0.00
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    ai_similar_listings_v2_nan_nan  ai_show_view_p3  ai_show_nan_nan  \
# 0                            0.00             0.00             0.00
# 1                             NaN              NaN              NaN
# 2                            0.00             0.00             0.00
# 3                             NaN             0.00              NaN
# 4                             NaN             0.00              NaN
#
#    ai_how_it_works_-unknown-_-unknown-  ai_dashboard_view_dashboard  \
# 0                                 0.00                         0.00
# 1                                  NaN                         0.00
# 2                                  NaN                         0.00
# 3                                  NaN                          NaN
# 4                                  NaN                         0.00
#
#    ai_header_userpic_data_header_userpic  \
# 0                                   0.00
# 1                                   0.00
# 2                                   0.00
# 3                                    NaN
# 4                                   0.00
#
#    ai_ajax_refresh_subtotal_click_change_trip_characteristics  \
# 0                                               0.00
# 1                                                NaN
# 2                                               0.00
# 3                                                NaN
# 4                                                NaN
#
#    ai_personalize_data_wishlist_content_update  \
# 0                                         0.00
# 1                                          NaN
# 2                                         0.00
# 3                                          NaN
# 4                                          NaN
#
#    ai_index_view_view_search_results  ai_index_-unknown-_-unknown-  \
# 0                               0.00                          0.00
# 1                                NaN                          0.00
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    ai_authenticate_view_login_page  ai_referrer_status_-unknown-_-unknown-  \
# 0                              NaN                                     NaN
# 1                             0.00                                    0.00
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4                             0.00                                     NaN
#
#    ai_create_multiple_-unknown-_-unknown-  ai_create_submit_create_user  \
# 0                                     NaN                           NaN
# 1                                    0.00                           NaN
# 2                                     NaN                          0.00
# 3                                     NaN                           NaN
# 4                                     NaN                           NaN
#
#    ai_show_view_user_profile  ai_ask_question_submit_contact_host  \
# 0                        NaN                                  NaN
# 1                        NaN                                  NaN
# 2                       0.00                                 0.00
# 3                       0.00                                  NaN
# 4                       0.00                                  NaN
#
#    ai_profile_pic_-unknown-_-unknown-  \
# 0                                 NaN
# 1                                 NaN
# 2                                0.00
# 3                                 NaN
# 4                                 NaN
#
#    ai_ajax_check_dates_click_change_contact_host_dates  \
# 0                                                NaN
# 1                                                NaN
# 2                                               0.00
# 3                                                NaN
# 4                                                NaN
#
#    ai_edit_view_edit_profile  ai_update_-unknown-_-unknown-  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                       0.00                           0.00
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    ai_show_personalize_data_user_profile_content_update  \
# 0                                                NaN
# 1                                                NaN
# 2                                               0.00
# 3                                                NaN
# 4                                                NaN
#
#    ai_notifications_view_account_notification_settings  \
# 0                                                NaN
# 1                                                NaN
# 2                                               0.00
# 3                                                NaN
# 4                                                NaN
#
#    ai_delete_-unknown-_-unknown-  ai_open_graph_setting_-unknown-_-unknown-  \
# 0                            NaN                                        NaN
# 1                            NaN                                        NaN
# 2                           0.00                                       0.00
# 3                            NaN                                        NaN
# 4                            NaN                                        NaN
#
#    ai_update_submit_update_user_profile  \
# 0                                   NaN
# 1                                   NaN
# 2                                  0.00
# 3                                   NaN
# 4                                   NaN
#
#    ai_ajax_lwlb_contact_click_contact_host  ai_impressions_view_p4  \
# 0                                      NaN                     NaN
# 1                                      NaN                     NaN
# 2                                     0.00                    0.00
# 3                                      NaN                     NaN
# 4                                      NaN                     NaN
#
#    ai_message_to_host_focus_click_message_to_host_focus  \
# 0                                                NaN
# 1                                                NaN
# 2                                               0.00
# 3                                                NaN
# 4                                                NaN
#
#    ai_ajax_image_upload_-unknown-_-unknown-  ai_update_submit_update_listing  \
# 0                                       NaN                              NaN
# 1                                       NaN                              NaN
# 2                                      0.00                             0.00
# 3                                       NaN                              NaN
# 4                                       NaN                              NaN
#
#    ai_populate_help_dropdown_-unknown-_-unknown-  \
# 0                                            NaN
# 1                                            NaN
# 2                                           0.00
# 3                                            NaN
# 4                                            NaN
#
#    ai_nan_message_post_message_post  ai_create_submit_signup  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                              0.00                      NaN
# 3                               NaN                     0.00
# 4                               NaN                      NaN
#
#    ai_reviews_data_listing_reviews  ai_active_-unknown-_-unknown-  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                             0.00                           0.00
# 4                             0.00                           0.00
#
#    ai_index_data_reservations  ai_unavailabilities_data_unavailable_dates  \
# 0                         NaN                                         NaN
# 1                         NaN                                         NaN
# 2                         NaN                                         NaN
# 3                        0.00                                        0.00
# 4                         NaN                                        0.00
#
#    ai_campaigns_nan_nan  ai_payment_instruments_data_payment_instruments  \
# 0                   NaN                                              NaN
# 1                   NaN                                              NaN
# 2                   NaN                                              NaN
# 3                  0.00                                             0.00
# 4                   NaN                                              NaN
#
#    ai_social_connections_data_user_social_connections  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               0.00
# 4                                                NaN
#
#    ai_search_click_view_search_results  ai_show_view_view_listing  \
# 0                                  NaN                        NaN
# 1                                  NaN                        NaN
# 2                                  NaN                        NaN
# 3                                 0.00                        NaN
# 4                                 0.00                       0.00
#
#    ai_confirm_email_click_confirm_email_link  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                       0.00
#
#    ai_collections_view_user_wishlists  ai_authenticate_submit_login  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                                 NaN                           NaN
# 4                                 NaN                           NaN
#
#    ai_set_user_submit_create_listing  ai_manage_listing_view_manage_listing  \
# 0                                NaN                                    NaN
# 1                                NaN                                    NaN
# 2                                NaN                                    NaN
# 3                                NaN                                    NaN
# 4                                NaN                                    NaN
#
#    ai_phone_verification_modal_-unknown-_-unknown-  ai_show_view_p1  \
# 0                                              NaN              NaN
# 1                                              NaN              NaN
# 2                                              NaN              NaN
# 3                                              NaN              NaN
# 4                                              NaN              NaN
#
#    ai_index_view_listing_descriptions  ai_new_view_list_your_space  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
#
#    ai_create_view_list_your_space  ai_verify_-unknown-_-unknown-  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    ai_create_submit_create_phone_numbers  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    ai_update_submit_update_listing_description  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    ai_pending_booking_request_pending  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    ai_agree_terms_check_-unknown-_-unknown-  ai_requested_view_p5  \
# 0                                       NaN                   NaN
# 1                                       NaN                   NaN
# 2                                       NaN                   NaN
# 3                                       NaN                   NaN
# 4                                       NaN                   NaN
#
#    ai_requested_submit_post_checkout_action  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    ai_message_to_host_change_click_message_to_host_change  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_similar_listings_data_similar_listings  ai_lookup_nan_nan  \
# 0                                        NaN                NaN
# 1                                        NaN                NaN
# 2                                        NaN                NaN
# 3                                        NaN                NaN
# 4                                        NaN                NaN
#
#    ai_index_view_message_thread  ai_qt2_view_message_thread  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#    ai_settings_-unknown-_-unknown-  ai_show_-unknown-_-unknown-  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
#
#    ai_update_submit_update_user  ai_notifications_submit_notifications  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
#
#    ai_cancellation_policies_view_cancellation_policies  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_signup_login_view_signup_login_page  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ai_cancellation_policy_click_click_cancellation_policy_click  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_recommend_-unknown-_-unknown-  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    ai_phone_verification_number_sucessfully_submitted_-unknown-_-unknown-  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_phone_verification_number_submitted_for_sms_-unknown-_-unknown-  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_endpoint_error_-unknown-_-unknown-  ai_login_view_login_page  \
# 0                                    NaN                       NaN
# 1                                    NaN                       NaN
# 2                                    NaN                       NaN
# 3                                    NaN                       NaN
# 4                                    NaN                       NaN
#
#    ai_index_view_message_inbox  ai_available_data_trip_availability  \
# 0                          NaN                                  NaN
# 1                          NaN                                  NaN
# 2                          NaN                                  NaN
# 3                          NaN                                  NaN
# 4                          NaN                                  NaN
#
#    ai_index_nan_nan  ai_create_-unknown-_-unknown-  \
# 0               NaN                            NaN
# 1               NaN                            NaN
# 2               NaN                            NaN
# 3               NaN                            NaN
# 4               NaN                            NaN
#
#    ai_reviews_data_user_reviews  ai_connect_submit_oauth_login  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#    ai_track_page_view_nan_nan  ai_popular_view_popular_wishlists  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4                         NaN                                NaN
#
#    ai_payment_methods_-unknown-_-unknown-  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ai_coupon_code_click_click_coupon_code_click  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ai_read_policy_click_click_read_policy_click  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ai_other_hosting_reviews_first_-unknown-_-unknown-  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_edit_verification_view_profile_verifications  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ai_travel_plans_current_view_your_trips  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    ai_qt_reply_v2_submit_send_message  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    ai_handle_vanity_url_-unknown-_-unknown-  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    ai_phone_number_widget_-unknown-_-unknown-  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    ai_update_notifications_-unknown-_-unknown-  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    ai_languages_multiselect_-unknown-_-unknown-  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ai_listings_view_user_listings  ai_apply_code_-unknown-_-unknown-  \
# 0                             NaN                                NaN
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                             NaN                                NaN
#
#    ai_create_submit_create_listing  ai_identity_-unknown-_-unknown-  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#    ai_kba_-unknown-_-unknown-  ai_kba_update_-unknown-_-unknown-  \
# 0                         NaN                                NaN
# 1                         NaN                                NaN
# 2                         NaN                                NaN
# 3                         NaN                                NaN
# 4                         NaN                                NaN
#
#    ai_jumio_token_-unknown-_-unknown-  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    ai_at_checkpoint_booking_request_at_checkpoint  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    ai_jumio_redirect_-unknown-_-unknown-  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    ai_transaction_history_view_account_transaction_history  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_account_-unknown-_-unknown-  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#    ai_recommendations_data_listing_recommendations  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ai_faq_-unknown-_-unknown-  ai_faq_category_-unknown-_-unknown-  \
# 0                         NaN                                  NaN
# 1                         NaN                                  NaN
# 2                         NaN                                  NaN
# 3                         NaN                                  NaN
# 4                         NaN                                  NaN
#
#    ai_localization_settings_nan_nan  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    ai_ajax_photo_widget_form_iframe_-unknown-_-unknown-  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_notifications_data_notifications  ai_reviews_new_-unknown-_-unknown-  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
#
#    ai_signature_-unknown-_-unknown-  ai_spoken_languages_data_user_languages  \
# 0                               NaN                                      NaN
# 1                               NaN                                      NaN
# 2                               NaN                                      NaN
# 3                               NaN                                      NaN
# 4                               NaN                                      NaN
#
#    ai_click_click_book_it  ai_calendar_tab_inner2_-unknown-_-unknown-  \
# 0                     NaN                                         NaN
# 1                     NaN                                         NaN
# 2                     NaN                                         NaN
# 3                     NaN                                         NaN
# 4                     NaN                                         NaN
#
#    ai_privacy_view_account_privacy_settings  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    ai_references_view_profile_references  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    ai_complete_status_-unknown-_-unknown-  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ai_complete_redirect_-unknown-_-unknown-  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    ai_phone_verification_success_click_phone_verification_success  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_terms_view_terms_and_privacy  ai_click_click_instant_book  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
#
#    ai_ajax_statsd_-unknown-_-unknown-  ai_tell_a_friend_-unknown-_-unknown-  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
#
#    ai_signup_modal_view_signup_modal  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    ai_facebook_auto_login_-unknown-_-unknown-  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    ai_phone_verification_phone_number_removed_-unknown-_-unknown-  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_request_new_confirm_email_click_request_new_confirm_email  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_receipt_view_guest_receipt  ai_index_view_your_listings  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#    ai_change_currency_-unknown-_-unknown-  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ai_delete_submit_delete_phone_numbers  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    ai_guest_billing_receipt_-unknown-_-unknown-  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ai_phone_verification_number_submitted_for_call_-unknown-_-unknown-  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_populate_from_facebook_-unknown-_-unknown-  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    ai_ajax_google_translate_description_-unknown-_-unknown-  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_hospitality_-unknown-_-unknown-  ai_host_summary_view_host_home  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
#
#    ai_my_listings_view_your_reservations  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    ai_ajax_google_translate_reviews_click_translate_listing_reviews  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_country_options_-unknown-_-unknown-  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ai_payout_preferences_view_account_payout_preferences  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_index_data_user_tax_forms  ai_top_destinations_-unknown-_-unknown-  \
# 0                           NaN                                      NaN
# 1                           NaN                                      NaN
# 2                           NaN                                      NaN
# 3                           NaN                                      NaN
# 4                           NaN                                      NaN
#
#    ai_change_view_change_or_alter  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#    ai_ajax_price_and_availability_click_alteration_field  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_create_submit_create_alteration_request  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    ai_recent_reservations_-unknown-_-unknown-  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    ai_listings_-unknown-_-unknown-  ai_decision_tree_-unknown-_-unknown-  \
# 0                              NaN                                   NaN
# 1                              NaN                                   NaN
# 2                              NaN                                   NaN
# 3                              NaN                                   NaN
# 4                              NaN                                   NaN
#
#    ai_index_view_user_wishlists  ai_my_view_user_wishlists  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
#
#    ai_mobile_landing_page_-unknown-_-unknown-  ai_currencies_nan_nan  \
# 0                                         NaN                    NaN
# 1                                         NaN                    NaN
# 2                                         NaN                    NaN
# 3                                         NaN                    NaN
# 4                                         NaN                    NaN
#
#    ai_show_view_wishlist  ai_add_note_submit_wishlist_note  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    ai_p4_terms_click_p4_terms  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#    ai_p4_refund_policy_terms_click_p4_refund_policy_terms  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_itinerary_view_guest_itinerary  ai_webcam_upload_-unknown-_-unknown-  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
# 2                                NaN                                   NaN
# 3                                NaN                                   NaN
# 4                                NaN                                   NaN
#
#    ai_guest_booked_elsewhere_message_post_message_post  ai_uptodate_nan_nan  \
# 0                                                NaN                    NaN
# 1                                                NaN                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#    ai_review_page_-unknown-_-unknown-  ai_glob_-unknown-_-unknown-  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
#
#    ai_apply_coupon_error_click_apply_coupon_error  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    ai_apply_coupon_error_type_-unknown-_-unknown-  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    ai_apply_reservation_submit_apply_coupon  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    ai_coupon_field_focus_click_coupon_field_focus  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    ai_login_modal_view_login_modal  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#    ai_apply_coupon_click_click_apply_coupon_click  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    ai_airbnb_picks_view_airbnb_picks_wishlists  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    ai_push_notification_callback_-unknown-_-unknown-  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_about_us_-unknown-_-unknown-  ai_pay_-unknown-_-unknown-  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
#
#    ai_supported_-unknown-_-unknown-  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    ai_mobile_oauth_callback_-unknown-_-unknown-  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ai_upload_-unknown-_-unknown-  ai_10_message_post_message_post  \
# 0                            NaN                              NaN
# 1                            NaN                              NaN
# 2                            NaN                              NaN
# 3                            NaN                              NaN
# 4                            NaN                              NaN
#
#    ai_clear_reservation_-unknown-_-unknown-  ai_click_click_request_to_book  \
# 0                                       NaN                             NaN
# 1                                       NaN                             NaN
# 2                                       NaN                             NaN
# 3                                       NaN                             NaN
# 4                                       NaN                             NaN
#
#    ai_set_password_view_set_password_page  ai_signed_out_modal_nan_nan  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#    ai_set_password_submit_set_password  ai_salute_-unknown-_-unknown-  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# ...
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    ai_complete_-unknown-_-unknown-  ai_locations_-unknown-_-unknown-  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#    ai_localized_-unknown-_-unknown-  ai_domains_-unknown-_-unknown-  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
#
#    ai_acculynk_session_obtained_-unknown-_-unknown-  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    ai_acculynk_bin_check_success_-unknown-_-unknown-  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_acculynk_load_pin_pad_-unknown-_-unknown-  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ai_new_session_-unknown-_-unknown-  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    ai_open_hard_fallback_modal_-unknown-_-unknown-  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ai_image_order_-unknown-_-unknown-  ai_life_-unknown-_-unknown-  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
#
#    ai_press_news_-unknown-_-unknown-  ai_envoy_form_-unknown-_-unknown-  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    ai_city_count_-unknown-_-unknown-  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    ai_print_confirmation_-unknown-_-unknown-  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ai_other_hosting_reviews_-unknown-_-unknown-  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ai_detect_fb_session_-unknown-_-unknown-  ai_founders_-unknown-_-unknown-  \
# 0                                       NaN                              NaN
# 1                                       NaN                              NaN
# 2                                       NaN                              NaN
# 3                                       NaN                              NaN
# 4                                       NaN                              NaN
#
#    ai_united-states_-unknown-_-unknown-  ai_signup_weibo_-unknown-_-unknown-  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#    ai_qt_reply_v2_-unknown-_-unknown-  ai_show_view_alteration_request  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN                              NaN
#
#    ai_respond_submit_respond_to_alteration_request  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ai_sublets_-unknown-_-unknown-  ai_slideshow_-unknown-_-unknown-  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
#
#    ai_create_paypal_-unknown-_-unknown-  ai_questions_-unknown-_-unknown-  \
# 0                                   NaN                               NaN
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
#
#    ai_media_resources_-unknown-_-unknown-  ai_views_-unknown-_-unknown-  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3                                     NaN                           NaN
# 4                                     NaN                           NaN
#
#    ai_photography_update_-unknown-_-unknown-  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ai_payoneer_account_redirect_-unknown-_-unknown-  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    ai_social_-unknown-_-unknown-  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#    ai_change_default_payout_-unknown-_-unknown-  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    ai_home_safety_terms_-unknown-_-unknown-  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    ai_ajax_special_offer_dates_available_click_special_offer_field  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_payout_delete_-unknown-_-unknown-  ai_sync_-unknown-_-unknown-  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    ai_new_-unknown-_-unknown-  ai_toggle_availability_-unknown-_-unknown-  \
# 0                         NaN                                         NaN
# 1                         NaN                                         NaN
# 2                         NaN                                         NaN
# 3                         NaN                                         NaN
# 4                         NaN                                         NaN
#
#    ai_load_more_-unknown-_-unknown-  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    ai_acculynk_pin_pad_inactive_-unknown-_-unknown-  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    ai_add_guests_-unknown-_-unknown-  ai_set_default_-unknown-_-unknown-  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#    ai_preapproval_message_post_message_post  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    ai_envoy_bank_details_redirect_-unknown-_-unknown-  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ai_badge_-unknown-_-unknown-  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#    ai_payoneer_signup_complete_-unknown-_-unknown-  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ai_social-media_-unknown-_-unknown-  ai_approve_submit_host_respond  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                                  NaN                             NaN
# 4                                  NaN                             NaN
#
#    ai_booking_booking_response_booking  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    ai_has_profile_pic_-unknown-_-unknown-  ai_feed_-unknown-_-unknown-  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#    ai_southern-europe_-unknown-_-unknown-  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    ai_maybe_information_message_post_message_post  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    ai_special_offer_message_post_message_post  ai_track_activity_nan_nan  \
# 0                                         NaN                        NaN
# 1                                         NaN                        NaN
# 2                                         NaN                        NaN
# 3                                         NaN                        NaN
# 4                                         NaN                        NaN
#
#    ai_phone_verification_nan_nan  ai_satisfy_nan_nan  \
# 0                            NaN                 NaN
# 1                            NaN                 NaN
# 2                            NaN                 NaN
# 3                            NaN                 NaN
# 4                            NaN                 NaN
#
#    ai_ajax_payout_split_edit_-unknown-_-unknown-  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    ai_reputation_-unknown-_-unknown-  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    ai_recommendation_page_-unknown-_-unknown-  ai_approve_-unknown-_-unknown-
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
# time: 270 ms (started: 2021-08-16 10:06:15 +00:00)

# %%
tmp.drop('action_info', axis=1, inplace=True)
# Out:
# time: 178 ms (started: 2021-08-16 10:06:16 +00:00)

# %% [markdown]
# #### Checking counts of missing values per each column

# %%
not_missing = pd.DataFrame(tmp.notna().sum()).reset_index()
not_missing.columns = ['col', 'counts']
not_missing['ratio'] = not_missing['counts'].apply(lambda x: round(x / len(users), 4))
not_missing.shape
# Out:
# (338, 3)
# time: 116 ms (started: 2021-08-16 10:06:16 +00:00)

# %%
not_missing.head()
# Out:
#                                            col  counts  ratio
# 0                                      user_id   61664   0.99
# 1                              seassion_length   61664   0.99
# 2  ai_callback_partner_callback_oauth_response    9094   0.15
# 3  ai_search_results_click_view_search_results   18356   0.30
# 4               ai_similar_listings_v2_nan_nan   18097   0.29
# time: 16.4 ms (started: 2021-08-16 10:06:16 +00:00)

# %%
threshold = 0.00005
mask = not_missing.ratio > threshold
mask.sum()
# Out:
# 303
# time: 10.2 ms (started: 2021-08-16 10:06:16 +00:00)

# %% [markdown]
# #### Dropping all columns that are lower than the above threshold

# %%
keep_columns = not_missing[mask].col.tolist()
len(keep_columns)
# Out:
# 303
# time: 11.8 ms (started: 2021-08-16 10:06:16 +00:00)

# %%
keep_columns[0], keep_columns[-1]
# Out:
# ('user_id', 'ai_add_guests_-unknown-_-unknown-')
# time: 9.19 ms (started: 2021-08-16 10:06:16 +00:00)

# %%
features1 = tmp[keep_columns].copy(deep=True)
features1.shape
# Out:
# (61664, 303)
# time: 147 ms (started: 2021-08-16 10:06:16 +00:00)

# %% [markdown]
# ### 2.1.1 Count of each action_type normalized

# %%
col = 'action_type'
col_values = list(sessions[col].unique())
len(col_values)
# Out:
# 10
# time: 396 ms (started: 2021-08-16 10:06:16 +00:00)

# %%
tmp = sessions[['user_id', col]].groupby('user_id', as_index=False).agg(list)
tmp.shape
# Out:
# (61664, 2)
# time: 3.04 s (started: 2021-08-16 10:06:17 +00:00)

# %%
tmp['size'] = tmp[col].apply(lambda x: len(x))
# Out:
# time: 75.9 ms (started: 2021-08-16 10:06:20 +00:00)

# %%
tmp['counts'] = tmp[col].apply(lambda x: dict(Counter(x)))
# Out:
# time: 791 ms (started: 2021-08-16 10:06:20 +00:00)

# %%
tmp.head()
# Out:
#       user_id                                        action_type  size  \
# 0  0010k6l0om  [partner_callback, click, None, view, None, No...    62
# 1  0031awlkjq  [view, view, -unknown-, data, view, -unknown-,...     8
# 2  00378ocvlh  [submit, None, data, click, view, None, submit...    73
# 3  0048rkdgb1  [submit, view, data, view, view, view, -unknow...    46
# 4  0057snrdpu  [view, view, view, data, view, view, view, dat...    28
#
#                                               counts
# 0  {'partner_callback': 1, 'click': 16, None: 15,...
# 1             {'view': 3, '-unknown-': 4, 'data': 1}
# 2  {'submit': 5, None: 4, 'data': 4, 'click': 5, ...
# 3  {'submit': 1, 'view': 20, 'data': 19, '-unknow...
# 4  {'view': 11, 'data': 8, 'click': 7, '-unknown-...
# time: 32.4 ms (started: 2021-08-16 10:06:21 +00:00)

# %%
tmp = pd.concat([tmp, pd.json_normalize(tmp['counts'])], axis=1)
# Out:
# time: 710 ms (started: 2021-08-16 10:06:21 +00:00)

# %%
tmp.drop(['action_type', 'counts'], axis=1, inplace=True)
# Out:
# time: 19.6 ms (started: 2021-08-16 10:06:21 +00:00)

# %%
tmp.head()
# Out:
#       user_id  size  partner_callback  click   NaN  view  -unknown-  data  \
# 0  0010k6l0om    62              1.00  16.00 15.00 17.00       4.00  9.00
# 1  0031awlkjq     8               NaN    NaN   NaN  3.00       4.00  1.00
# 2  00378ocvlh    73               NaN   5.00  4.00 34.00      20.00  4.00
# 3  0048rkdgb1    46               NaN   4.00  1.00 20.00       1.00 19.00
# 4  0057snrdpu    28               NaN   7.00   NaN 11.00       2.00  8.00
#
#    submit  message_post  booking_request  booking_response
# 0     NaN           NaN              NaN               NaN
# 1     NaN           NaN              NaN               NaN
# 2    5.00          1.00              NaN               NaN
# 3    1.00           NaN              NaN               NaN
# 4     NaN           NaN              NaN               NaN
# time: 40.1 ms (started: 2021-08-16 10:06:21 +00:00)

# %%
cols = list(tmp)[2:]
cols = [f'at_{e}' for e in cols]
# Out:
# time: 1.18 ms (started: 2021-08-16 10:06:21 +00:00)

# %%
tmp.columns = ['user_id', 'size'] + cols
# Out:
# time: 859 µs (started: 2021-08-16 10:06:21 +00:00)

# %%
for e in cols:
    tmp[e] = tmp[e] / tmp['size']
# Out:
# time: 25.3 ms (started: 2021-08-16 10:06:21 +00:00)

# %%
tmp.head()
# Out:
#       user_id  size  at_partner_callback  at_click  at_None  at_view  \
# 0  0010k6l0om    62                 0.02      0.26     0.24     0.27
# 1  0031awlkjq     8                  NaN       NaN      NaN     0.38
# 2  00378ocvlh    73                  NaN      0.07     0.05     0.47
# 3  0048rkdgb1    46                  NaN      0.09     0.02     0.43
# 4  0057snrdpu    28                  NaN      0.25      NaN     0.39
#
#    at_-unknown-  at_data  at_submit  at_message_post  at_booking_request  \
# 0          0.06     0.15        NaN              NaN                 NaN
# 1          0.50     0.12        NaN              NaN                 NaN
# 2          0.27     0.05       0.07             0.01                 NaN
# 3          0.02     0.41       0.02              NaN                 NaN
# 4          0.07     0.29        NaN              NaN                 NaN
#
#    at_booking_response
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# time: 29.9 ms (started: 2021-08-16 10:06:22 +00:00)

# %%
tmp.drop(['size'], axis=1, inplace=True)
# Out:
# time: 27.5 ms (started: 2021-08-16 10:06:22 +00:00)

# %%
tmp.fillna(0, inplace=True)
# Out:
# time: 32.3 ms (started: 2021-08-16 10:06:22 +00:00)

# %%
tmp.head()
# Out:
#       user_id  at_partner_callback  at_click  at_None  at_view  at_-unknown-  \
# 0  0010k6l0om                 0.02      0.26     0.24     0.27          0.06
# 1  0031awlkjq                 0.00      0.00     0.00     0.38          0.50
# 2  00378ocvlh                 0.00      0.07     0.05     0.47          0.27
# 3  0048rkdgb1                 0.00      0.09     0.02     0.43          0.02
# 4  0057snrdpu                 0.00      0.25     0.00     0.39          0.07
#
#    at_data  at_submit  at_message_post  at_booking_request  \
# 0     0.15       0.00             0.00                0.00
# 1     0.12       0.00             0.00                0.00
# 2     0.05       0.07             0.01                0.00
# 3     0.41       0.02             0.00                0.00
# 4     0.29       0.00             0.00                0.00
#
#    at_booking_response
# 0                 0.00
# 1                 0.00
# 2                 0.00
# 3                 0.00
# 4                 0.00
# time: 29.1 ms (started: 2021-08-16 10:06:22 +00:00)

# %%
features1a = tmp.copy(deep=True)
features1a.shape
# Out:
# (61664, 11)
# time: 14.8 ms (started: 2021-08-16 10:06:22 +00:00)

# %% [markdown]
# ### 2.2 Generating features based on seconds elapsed info

# %%
tmp = sessions[['user_id', 'secs_elapsed']].groupby('user_id', as_index=False).agg(list)
tmp.shape
# Out:
# (61664, 2)
# time: 3.19 s (started: 2021-08-16 10:06:22 +00:00)

# %%
tmp.head()
# Out:
#       user_id                                       secs_elapsed
# 0  0010k6l0om  [-1.0, 3.0, 9.0, 22.0, 26.0, 30.0, 34.0, 36.0,...
# 1  0031awlkjq  [-1.0, 388.0, 642.0, 719.0, 1675.0, 2795.0, 97...
# 2  00378ocvlh  [-1.0, 14.0, 19.0, 23.0, 24.0, 155.0, 166.0, 2...
# 3  0048rkdgb1  [-1.0, 7.0, 19.0, 27.0, 48.0, 49.0, 52.0, 59.0...
# 4  0057snrdpu  [-1.0, 41.0, 54.0, 65.0, 84.0, 112.0, 178.0, 2...
# time: 20.9 ms (started: 2021-08-16 10:06:25 +00:00)

# %%
tmp.secs_elapsed = tmp.secs_elapsed.apply(lambda x: [0] + x[1:])
# Out:
# time: 650 ms (started: 2021-08-16 10:06:25 +00:00)

# %%
tmp['deltas'] = tmp['secs_elapsed'].apply(lambda x: [int(j - i) for i, j in zip(x[:-1], x[1:])])
# Out:
# time: 1.9 s (started: 2021-08-16 10:06:26 +00:00)

# %%
tmp.head()
# Out:
#       user_id                                       secs_elapsed  \
# 0  0010k6l0om  [0, 3.0, 9.0, 22.0, 26.0, 30.0, 34.0, 36.0, 39...
# 1  0031awlkjq  [0, 388.0, 642.0, 719.0, 1675.0, 2795.0, 9797....
# 2  00378ocvlh  [0, 14.0, 19.0, 23.0, 24.0, 155.0, 166.0, 269....
# 3  0048rkdgb1  [0, 7.0, 19.0, 27.0, 48.0, 49.0, 52.0, 59.0, 5...
# 4  0057snrdpu  [0, 41.0, 54.0, 65.0, 84.0, 112.0, 178.0, 248....
#
#                                               deltas
# 0  [3, 6, 13, 4, 4, 4, 2, 3, 6, 1, 3, 4, 30, 8, 1...
# 1             [388, 254, 77, 956, 1120, 7002, 13761]
# 2  [14, 5, 4, 1, 131, 11, 103, 23, 15, 23, 6, 29,...
# 3  [7, 12, 8, 21, 1, 3, 7, 0, 1, 1, 8, 4, 23, 1, ...
# 4  [41, 13, 11, 19, 28, 66, 70, 134, 30, 10, 222,...
# time: 29.5 ms (started: 2021-08-16 10:06:28 +00:00)

# %%
def get_statistics(x):
    if not x:
        return None, None, None, None
    x = np.array(x)
    return x.mean(), x.std(), x.max(), np.median(x)
# Out:
# time: 7.96 ms (started: 2021-08-16 10:06:28 +00:00)

# %%
def get_statistics_no_outliers(x):
    if not x:
        return None, None, None, None, None
    x = np.array(x)
    initial_size = len(x)
    x = [e for e in x if e <= x.mean() + x.std()]
    outliers_count = initial_size - len(x)
    x = np.array(x)
    return x.mean(), x.std(), x.max(), np.median(x), outliers_count
# Out:
# time: 7.64 ms (started: 2021-08-16 10:06:28 +00:00)

# %%
get_statistics(tmp.iloc[0].deltas)
# Out:
# (2096.688524590164, 6051.6816645092, 34874, 31.0)
# time: 10.3 ms (started: 2021-08-16 10:06:28 +00:00)

# %%
get_statistics_no_outliers(tmp.iloc[0].deltas)
# Out:
# (704.280701754386, 1636.6660780474087, 8000, 24.0, 4)
# time: 13.2 ms (started: 2021-08-16 10:06:28 +00:00)

# %%
tmp = pd.concat([tmp, tmp.deltas.progress_apply(lambda x: pd.Series(get_statistics(x)))], axis=1)
tmp.shape
# Out:
#   0%|          | 0/61664 [00:00<?, ?it/s]
# (61664, 7)
# time: 36.9 s (started: 2021-08-16 10:06:28 +00:00)

# %%
tmp.columns = ['user_id', 'secs_elapsed', 'deltas', 'deltas_mean', 'deltas_std', 'deltas_max', 'deltas_median']
# Out:
# time: 1.62 ms (started: 2021-08-16 10:07:05 +00:00)

# %%
tmp.head()
# Out:
#       user_id                                       secs_elapsed  \
# 0  0010k6l0om  [0, 3.0, 9.0, 22.0, 26.0, 30.0, 34.0, 36.0, 39...
# 1  0031awlkjq  [0, 388.0, 642.0, 719.0, 1675.0, 2795.0, 9797....
# 2  00378ocvlh  [0, 14.0, 19.0, 23.0, 24.0, 155.0, 166.0, 269....
# 3  0048rkdgb1  [0, 7.0, 19.0, 27.0, 48.0, 49.0, 52.0, 59.0, 5...
# 4  0057snrdpu  [0, 41.0, 54.0, 65.0, 84.0, 112.0, 178.0, 248....
#
#                                               deltas  deltas_mean  deltas_std  \
# 0  [3, 6, 13, 4, 4, 4, 2, 3, 6, 1, 3, 4, 30, 8, 1...      2096.69     6051.68
# 1             [388, 254, 77, 956, 1120, 7002, 13761]      3365.43     4803.27
# 2  [14, 5, 4, 1, 131, 11, 103, 23, 15, 23, 6, 29,...      8391.38    46492.00
# 3  [7, 12, 8, 21, 1, 3, 7, 0, 1, 1, 8, 4, 23, 1, ...      1992.78     7326.20
# 4  [41, 13, 11, 19, 28, 66, 70, 134, 30, 10, 222,...     37878.26   181708.52
#
#    deltas_max  deltas_median
# 0    34874.00          31.00
# 1    13761.00         956.00
# 2   386212.00          78.00
# 3    48094.00          35.00
# 4   964245.00         402.00
# time: 83.4 ms (started: 2021-08-16 10:07:05 +00:00)

# %%
tmp = pd.concat([tmp, tmp.deltas.progress_apply(lambda x: pd.Series(get_statistics_no_outliers(x)))], axis=1)
tmp.shape
# Out:
#   0%|          | 0/61664 [00:00<?, ?it/s]
# (61664, 12)
# time: 6min 59s (started: 2021-08-16 10:07:05 +00:00)

# %%
tmp.columns = [
    'user_id', 'secs_elapsed', 'deltas', 'deltas_mean', 'deltas_std', 'deltas_max', 'deltas_median', 
    'deltas_no_mean', 'deltas_no_std', 'deltas_no_max', 'deltas_no_median', 'deltas_no_num_outliers'
]
# Out:
# time: 1.51 ms (started: 2021-08-16 10:14:04 +00:00)

# %%
tmp.head()
# Out:
#       user_id                                       secs_elapsed  \
# 0  0010k6l0om  [0, 3.0, 9.0, 22.0, 26.0, 30.0, 34.0, 36.0, 39...
# 1  0031awlkjq  [0, 388.0, 642.0, 719.0, 1675.0, 2795.0, 9797....
# 2  00378ocvlh  [0, 14.0, 19.0, 23.0, 24.0, 155.0, 166.0, 269....
# 3  0048rkdgb1  [0, 7.0, 19.0, 27.0, 48.0, 49.0, 52.0, 59.0, 5...
# 4  0057snrdpu  [0, 41.0, 54.0, 65.0, 84.0, 112.0, 178.0, 248....
#
#                                               deltas  deltas_mean  deltas_std  \
# 0  [3, 6, 13, 4, 4, 4, 2, 3, 6, 1, 3, 4, 30, 8, 1...      2096.69     6051.68
# 1             [388, 254, 77, 956, 1120, 7002, 13761]      3365.43     4803.27
# 2  [14, 5, 4, 1, 131, 11, 103, 23, 15, 23, 6, 29,...      8391.38    46492.00
# 3  [7, 12, 8, 21, 1, 3, 7, 0, 1, 1, 8, 4, 23, 1, ...      1992.78     7326.20
# 4  [41, 13, 11, 19, 28, 66, 70, 134, 30, 10, 222,...     37878.26   181708.52
#
#    deltas_max  deltas_median  deltas_no_mean  deltas_no_std  deltas_no_max  \
# 0    34874.00          31.00          704.28        1636.67        8000.00
# 1    13761.00         956.00         1632.83        2429.69        7002.00
# 2   386212.00          78.00         1721.44        5115.18       28696.00
# 3    48094.00          35.00          513.98        1290.47        6839.00
# 4   964245.00         402.00         2248.77        3531.96       12416.00
#
#    deltas_no_median  deltas_no_num_outliers
# 0             24.00                    4.00
# 1            672.00                    1.00
# 2             71.00                    2.00
# 3             26.50                    3.00
# 4            328.50                    1.00
# time: 42.7 ms (started: 2021-08-16 10:14:04 +00:00)

# %%
tmp.drop(['secs_elapsed', 'deltas'], axis=1, inplace=True)
# Out:
# time: 39.2 ms (started: 2021-08-16 10:14:04 +00:00)

# %%
features2 = tmp.copy(deep=True)
features2.shape
# Out:
# (61664, 10)
# time: 15.6 ms (started: 2021-08-16 10:14:04 +00:00)

# %% [markdown]
# ### 2.3 Generating features based on device type info

# %%
tmp = sessions[['user_id', 'device_type']].groupby('user_id', as_index=False).agg(set)
tmp.shape
# Out:
# (61664, 2)
# time: 3.35 s (started: 2021-08-16 10:14:04 +00:00)

# %%
tmp['size'] = tmp.device_type.apply(lambda x: len(x))
# Out:
# time: 109 ms (started: 2021-08-16 10:14:08 +00:00)

# %%
tmp.drop('device_type', axis=1, inplace=True)
# Out:
# time: 36.5 ms (started: 2021-08-16 10:14:08 +00:00)

# %%
tmp.head()
# Out:
#       user_id  size
# 0  0010k6l0om     1
# 1  0031awlkjq     1
# 2  00378ocvlh     1
# 3  0048rkdgb1     1
# 4  0057snrdpu     2
# time: 23.9 ms (started: 2021-08-16 10:14:08 +00:00)

# %%
tmp.columns = ['user_id', 'device_count']
# Out:
# time: 1.06 ms (started: 2021-08-16 10:14:08 +00:00)

# %%
tmp.head()
# Out:
#       user_id  device_count
# 0  0010k6l0om             1
# 1  0031awlkjq             1
# 2  00378ocvlh             1
# 3  0048rkdgb1             1
# 4  0057snrdpu             2
# time: 27.3 ms (started: 2021-08-16 10:14:08 +00:00)

# %%
features3 = tmp.copy(deep=True)
features3.shape
# Out:
# (61664, 2)
# time: 9.36 ms (started: 2021-08-16 10:14:08 +00:00)

# %% [markdown]
# ### 3.1 Features based on Users table

# %%
users['dow_registered'] = users.date_account_created.dt.weekday
# Out:
# time: 22.2 ms (started: 2021-08-16 10:14:08 +00:00)

# %%
users['hr_registered'] = users.timestamp_first_active.dt.hour
# Out:
# time: 29 ms (started: 2021-08-16 10:14:08 +00:00)

# %%
users.sample(5)
# Out:
#                id date_account_created timestamp_first_active     gender  \
# 17509  zjoqoueotj           2014-07-26    2014-07-26 13:46:12  -unknown-
# 8083   ezbr8c52bv           2014-07-15    2014-07-15 15:42:34     FEMALE
# 24308  1jip44syma           2014-08-04    2014-08-04 23:33:25  -unknown-
# 26686  dkrva2il0x           2014-08-08    2014-08-08 01:45:58     FEMALE
# 62009  st4ctniau6           2014-09-30    2014-09-30 22:02:27       MALE
#
#          age signup_method  signup_flow language affiliate_channel  \
# 17509    NaN         basic            0       en            direct
# 8083   55.00      facebook            0       en           content
# 24308    NaN         basic           23       ko            direct
# 26686 105.00         basic            0       en            direct
# 62009  38.00         basic           25       en            direct
#
#       affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 17509             direct                  linked      Moweb            iPhone
# 8083              google                     omg        Web   Windows Desktop
# 24308             direct               untracked    Android     Android Phone
# 26686             direct               untracked        Web       Mac Desktop
# 62009             direct               untracked        iOS            iPhone
#
#        first_browser  dow_registered  hr_registered
# 17509  Mobile Safari               5             13
# 8083              IE               1             15
# 24308      -unknown-               0             23
# 26686         Chrome               4              1
# 62009      -unknown-               1             22
# time: 39.4 ms (started: 2021-08-16 10:14:08 +00:00)

# %% [markdown]
# ### 3.1.1. Dropping redundand columns

# %%
users.drop(['date_account_created', 'timestamp_first_active'], axis=1, inplace=True)
# Out:
# time: 20.4 ms (started: 2021-08-16 10:14:08 +00:00)

# %%
users.columns = ['user_id'] + list(users)[1:]
# Out:
# time: 2.58 ms (started: 2021-08-16 10:14:08 +00:00)

# %%
users.head()
# Out:
#       user_id     gender   age signup_method  signup_flow language  \
# 0  5uwns89zht     FEMALE 35.00      facebook            0       en
# 1  jtl0dijy2j  -unknown-   NaN         basic            0       en
# 2  xx0ulgorjt  -unknown-   NaN         basic            0       en
# 3  6c6puo6ix0  -unknown-   NaN         basic            0       en
# 4  czqhjk3yfe  -unknown-   NaN         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0            direct             direct               untracked      Moweb
# 1            direct             direct               untracked      Moweb
# 2            direct             direct                  linked        Web
# 3            direct             direct                  linked        Web
# 4            direct             direct               untracked        Web
#
#   first_device_type  first_browser  dow_registered  hr_registered
# 0            iPhone  Mobile Safari               1              0
# 1            iPhone  Mobile Safari               1              0
# 2   Windows Desktop         Chrome               1              0
# 3   Windows Desktop             IE               1              0
# 4       Mac Desktop         Safari               1              0
# time: 29.3 ms (started: 2021-08-16 10:14:08 +00:00)

# %%
users.shape
# Out:
# (62096, 14)
# time: 7.37 ms (started: 2021-08-16 10:14:08 +00:00)

# %% [markdown]
# #### 4. Assembling all features into one dataset

# %%
df = users.merge(features1, on='user_id', how='inner')
df.shape
# Out:
# (61664, 316)
# time: 385 ms (started: 2021-08-16 10:14:08 +00:00)

# %%
df = df.merge(features1a, on='user_id', how='inner')
df.shape
# Out:
# (61664, 326)
# time: 406 ms (started: 2021-08-16 10:14:09 +00:00)

# %%
df = df.merge(features2, on='user_id', how='inner')
df.shape
# Out:
# (61664, 335)
# time: 215 ms (started: 2021-08-16 10:14:09 +00:00)

# %%
df = df.merge(features3, on='user_id', how='inner')
df.shape
# Out:
# (61664, 336)
# time: 197 ms (started: 2021-08-16 10:14:09 +00:00)

# %%
df.to_parquet('../data/processed/features_test.parquet')
# Out:
# time: 1.59 s (started: 2021-08-16 10:14:10 +00:00)
